# %%
import pandas as pd

# %%
df = pd.read_csv('chq_22.csv')

# %%
df1 = df

# %%
df1
# Out:
#       4-Jan-22   All Steel Roofing & Electricals Inc.    Refer to Drawer  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#        $ 1,875.00    FCIB #2250  30/12/2021 Unnamed: 6 Unnamed: 7  \
# ...

# %%
df1.columns = ['debited', 'owners', 'reason', 'amount', 'chq_no', 'chq_dt', 'status', 'receipt_no', 'ministry', 'col']

# %%
df1
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#             amount       chq_no      chq_dt status receipt_no  \
# ...

# %%
df2 = df1.drop('col', axis=1)

# %%
df2
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#             amount       chq_no      chq_dt status receipt_no  \
# ...

# %%
df2['ministry'] = df2['ministry'].fillna(value='unknown')

# %%
df2
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#             amount       chq_no      chq_dt status receipt_no  \
# ...

# %%
df2['receipt_no'] = df2['receipt_no'].fillna(value='-')

# %%
df2
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#             amount       chq_no      chq_dt status receipt_no  \
# ...

# %%
df2
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#             amount       chq_no      chq_dt status receipt_no  \
# ...

# %%
mask = (df2['receipt_no'] == '-') & (df['status'].isna())
df2.loc[mask, 'status'] = 'UN'

# %%
df2
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#             amount       chq_no      chq_dt status receipt_no  \
# ...

# %%
count = df2['receipt_no'].isna().sum()

# %%
count
# Out:
# 0

# %%
df3=df2

# %%
df3
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#             amount       chq_no      chq_dt status receipt_no  \
# ...

# %%
df3['amount']=df3['amount'].str.replace('$', '').str.replace(',', '')

# %%
df3
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#           amount       chq_no      chq_dt status receipt_no          ministry
# ...

# %%
df3
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#           amount       chq_no      chq_dt status receipt_no          ministry
# ...

# %%
df3['chq_no']=df3['chq_no'].str.replace(' ', '').str.strip()

# %%
df3
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#           amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
count_1nb = df3['chq_no'].str.count('1NB').sum()

# %%
count_1nb
# Out:
# 34.0

# %%
df3['chq_no']=df3['chq_no'].str.replace('1NB', 'FNB').str.strip()

# %%
count_1nb = df3['chq_no'].str.count('1NB').sum()

# %%
count_1nb
# Out:
# 0.0

# %%
df4=df3

# %%
df4['chq_no']=df4['chq_no'].str.replace(' ', '')

# %%
df4['chq_no'] = df4['chq_no'].str.strip()

# %%
df4
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#           amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
count_sig = df4['reason'].str.count('Signature').sum()
count_miss = df4['reason'].str.count('Missing').sum()

# %%
print(count_sig, count_miss)
# Out:
# 13.0 13.0

# %%
df4.to_csv('chq_22_cln.csv')

# %%
df4
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 3    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# 4    17-Jan-22         Water and Sewerage Company Inc  Signature Missing
# ..         ...                                    ...                ...
# 123  20-Dec-22                             Verve Inc.    Refer to Drawer
# 124  21-Dec-22                 Frootsy  Foods Limited           No Payee
# 125  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 126  28-Dec-22               Ernst and Young Services     Refer to Maker
# 127  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#           amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
to_drop = df4[df4['reason'] == 'MAY']

# %%
to_drop.index
# Out:
# Index([], dtype='int64')

# %%
import pandas as pd

# %%
df5 = pd.read_csv('chq_22_clean.csv')

# %%
df5=df5.drop(columns='reason_x')

# %%
df5['reason']=df5['reason'].str.replace('Signature Missing', 'Missing Signature').str.replace('No Payee', 'Payee Missing')

# %%
df5=df5.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %%
df5['reason'].unique()
# Out:
# array(['Refer to Drawer', 'Missing Signature', 'Word & Figures Differ',
#        'Words & Figures Differ', '-', 'Invalid Routing Number',
#        'Stale Dated', 'Payment Stopped', 'Incomplete Date', 'Post Dated ',
#        'Post/Stale dated', 'Payee Missing', 'Refer to Maker'],
#       dtype=object)

# %%
df5['reason']=df5['reason'].str.replace('Word & Figures Differ', 'Figure and amount mismatch').str.replace('Words & Figures Differ', 'Figure and amount mismatch').str.replace('Incomplete Date', 'date missing')

# %%
df5
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Missing Signature
# 3    17-Jan-22         Water and Sewerage Company Inc  Missing Signature
# 4    17-Jan-22         Water and Sewerage Company Inc  Missing Signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             Verve Inc.    Refer to Drawer
# 120  21-Dec-22                 Frootsy  Foods Limited      Payee Missing
# 121  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 122  28-Dec-22               Ernst and Young Services     Refer to Maker
# 123  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#        amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
df5.to_csv('chq_22_clean.csv')

# %%
df5
# Out:
#      Unnamed: 0    debited                                 owners  \
# 0             0   5-Jan-22                           Port Express
# 1             1  12-Jan-22                   Mannee's Bakery Ltd.
# 2             2  17-Jan-22         Water and Sewerage Company Inc
# 3             3  17-Jan-22         Water and Sewerage Company Inc
# 4             4  17-Jan-22         Water and Sewerage Company Inc
# ..          ...        ...                                    ...
# 119         123  20-Dec-22                             Verve Inc.
# 120         124  21-Dec-22                 Frootsy  Foods Limited
# 121         125  21-Dec-22            J.E. Maxwell & Company Ltd.
# 122         126  28-Dec-22               Ernst and Young Services
# 123         127  29-Dec-22  Clean Ops Service Company (COSC) Inc.
#
#                 reason    amount      chq_no      chq_dt status receipt_no  \
# 0      Refer to Drawer  11635.71   BOSL#1324  31/12/2021     UN          -
# ...

# %%
df5['reason'].unique()
# Out:
# array(['Refer to Drawer', 'Missing Signature',
#        'Figure and amount mismatch', '-', 'Invalid Routing Number',
#        'Stale Dated', 'Payment Stopped', 'date missing', 'Post Dated ',
#        'Post/Stale dated', 'Payee Missing', 'Refer to Maker'],
#       dtype=object)

# %%
df5['reason_x']=df5['reason'].str.replace('Stale Dated', '6').str.replace('Payment Stopped', '12').str.replace('date missing', '9').str.replace('Post Dated ', '4')

# %%
df5
# Out:
#      Unnamed: 0    debited                                 owners  \
# 0             0   5-Jan-22                           Port Express
# 1             1  12-Jan-22                   Mannee's Bakery Ltd.
# 2             2  17-Jan-22         Water and Sewerage Company Inc
# 3             3  17-Jan-22         Water and Sewerage Company Inc
# 4             4  17-Jan-22         Water and Sewerage Company Inc
# ..          ...        ...                                    ...
# 119         123  20-Dec-22                             Verve Inc.
# 120         124  21-Dec-22                 Frootsy  Foods Limited
# 121         125  21-Dec-22            J.E. Maxwell & Company Ltd.
# 122         126  28-Dec-22               Ernst and Young Services
# 123         127  29-Dec-22  Clean Ops Service Company (COSC) Inc.
#
#                 reason    amount      chq_no      chq_dt status receipt_no  \
# 0      Refer to Drawer  11635.71   BOSL#1324  31/12/2021     UN          -
# ...

# %%
df5
# Out:
#      Unnamed: 0.1  Unnamed: 0    debited  \
# 0               0           0   5-Jan-22
# 1               1           1  12-Jan-22
# 2               2           2  17-Jan-22
# 3               3           3  17-Jan-22
# 4               4           4  17-Jan-22
# ..            ...         ...        ...
# 119           119         123  20-Dec-22
# 120           120         124  21-Dec-22
# 121           121         125  21-Dec-22
# 122           122         126  28-Dec-22
# 123           123         127  29-Dec-22
#
#                                     owners             reason    amount  \
# 0                             Port Express    Refer to Drawer  11635.71
# 1                     Mannee's Bakery Ltd.    Refer to Drawer   5236.20
# 2           Water and Sewerage Company Inc  Missing Signature  72979.66
# 3           Water and Sewerage Company Inc  Missing Signature  72979.66
# 4           Water and Sewerage Company Inc  Missing Signature  72979.67
# ...

# %%
df5
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           Port Express    Refer to Drawer
# 1    12-Jan-22                   Mannee's Bakery Ltd.    Refer to Drawer
# 2    17-Jan-22         Water and Sewerage Company Inc  Missing Signature
# 3    17-Jan-22         Water and Sewerage Company Inc  Missing Signature
# 4    17-Jan-22         Water and Sewerage Company Inc  Missing Signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             Verve Inc.    Refer to Drawer
# 120  21-Dec-22                 Frootsy  Foods Limited      Payee Missing
# 121  21-Dec-22            J.E. Maxwell & Company Ltd.    Refer to Drawer
# 122  28-Dec-22               Ernst and Young Services     Refer to Maker
# 123  29-Dec-22  Clean Ops Service Company (COSC) Inc.    Refer to Drawer
#
#        amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
df5['owners'] = df5['owners'].str.lower()

# %%
df5['reason'] = df5['reason'].str.lower()

# %%
df6=df5

# %%
df6['ministry'] = df6['ministry'].str.lower()
df6['status'] = df6['status'].str.lower()

# %%
df6
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           port express    refer to drawer
# 1    12-Jan-22                   mannee's bakery ltd.    refer to drawer
# 2    17-Jan-22         water and sewerage company inc  missing signature
# 3    17-Jan-22         water and sewerage company inc  missing signature
# 4    17-Jan-22         water and sewerage company inc  missing signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             verve inc.    refer to drawer
# 120  21-Dec-22                 frootsy  foods limited      payee missing
# 121  21-Dec-22            j.e. maxwell & company ltd.    refer to drawer
# 122  28-Dec-22               ernst and young services     refer to maker
# 123  29-Dec-22  clean ops service company (cosc) inc.    refer to drawer
#
#        amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
df6['chq_no'] = df6['chq_no'].str.lower()

# %%
df6
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           port express    refer to drawer
# 1    12-Jan-22                   mannee's bakery ltd.    refer to drawer
# 2    17-Jan-22         water and sewerage company inc  missing signature
# 3    17-Jan-22         water and sewerage company inc  missing signature
# 4    17-Jan-22         water and sewerage company inc  missing signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             verve inc.    refer to drawer
# 120  21-Dec-22                 frootsy  foods limited      payee missing
# 121  21-Dec-22            j.e. maxwell & company ltd.    refer to drawer
# 122  28-Dec-22               ernst and young services     refer to maker
# 123  29-Dec-22  clean ops service company (cosc) inc.    refer to drawer
#
#        amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
df6.to_csv('chq_22_clean_6.csv')

# %%
df6['reason_x']=df6['reason'].str.replace('Post/Stale dated','stale dated')

# %%
df6
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           port express    refer to drawer
# 1    12-Jan-22                   mannee's bakery ltd.    refer to drawer
# 2    17-Jan-22         water and sewerage company inc  missing signature
# 3    17-Jan-22         water and sewerage company inc  missing signature
# 4    17-Jan-22         water and sewerage company inc  missing signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             verve inc.    refer to drawer
# 120  21-Dec-22                 frootsy  foods limited      payee missing
# 121  21-Dec-22            j.e. maxwell & company ltd.    refer to drawer
# 122  28-Dec-22               ernst and young services     refer to maker
# 123  29-Dec-22  clean ops service company (cosc) inc.    refer to drawer
#
#        amount      chq_no      chq_dt status receipt_no          ministry  \
# ...

# %%
df6['reason'].unique()
# Out:
# array(['refer to drawer', 'missing signature',
#        'figure and amount mismatch', '-', 'invalid routing number',
#        'stale dated', 'payment stopped', 'date missing', 'post dated ',
#        'post/stale dated', 'payee missing', 'refer to maker'],
#       dtype=object)

# %%
df6['reason']=df6['reason'].str.replace('Post/Stale dated','stale dated')

# %%
df6['reason'].unique()
# Out:
# array(['refer to drawer', 'missing signature',
#        'figure and amount mismatch', '-', 'invalid routing number',
#        'stale dated', 'payment stopped', 'date missing', 'post dated ',
#        'post/stale dated', 'payee missing', 'refer to maker'],
#       dtype=object)

# %%
df7=pd.read_csv('chq_22_clean_6.csv')

# %%
df7.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df7
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           port express    refer to drawer
# 1    12-Jan-22                   mannee's bakery ltd.    refer to drawer
# 2    17-Jan-22         water and sewerage company inc  missing signature
# 3    17-Jan-22         water and sewerage company inc  missing signature
# 4    17-Jan-22         water and sewerage company inc  missing signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             verve inc.    refer to drawer
# 120  21-Dec-22                 frootsy  foods limited      payee missing
# 121  21-Dec-22            j.e. maxwell & company ltd.    refer to drawer
# 122  28-Dec-22               ernst and young services     refer to maker
# 123  29-Dec-22  clean ops service company (cosc) inc.    refer to drawer
#
#        amount      chq_no      chq_dt status receipt_no          ministry
# ...

# %%
df7['reason'].unique()
# Out:
# array(['refer to drawer', 'missing signature',
#        'figure and amount mismatch', '-', 'invalid routing number',
#        'stale dated', 'payment stopped', 'date missing', 'post dated ',
#        'post/stale dated', 'payee missing', 'refer to maker'],
#       dtype=object)

# %%
df7['reason']=df7['reason'].str.replace('post/stale dated','stale dated')

# %%
df7['reason'].unique()
# Out:
# array(['refer to drawer', 'missing signature',
#        'figure and amount mismatch', '-', 'invalid routing number',
#        'stale dated', 'payment stopped', 'date missing', 'post dated ',
#        'payee missing', 'refer to maker'], dtype=object)

# %%
df7['reason'].describe()
# Out:
# count                 124
# unique                 11
# top       refer to drawer
# freq                   63
# Name: reason, dtype: object

# %%
df7['reason']=df7['reason'].str.replace('-','refer to drawer')

# %%
df7['reason'].unique()
# Out:
# array(['refer to drawer', 'missing signature',
#        'figure and amount mismatch', 'invalid routing number',
#        'stale dated', 'payment stopped', 'date missing', 'post dated ',
#        'payee missing', 'refer to maker'], dtype=object)

# %%
df7.to_csv('chq_22_clean_8.csv')

# %%
df7['chq_dt'].describe()
# Out:
# count          124
# unique          88
# top       7/1/2022
# freq             7
# Name: chq_dt, dtype: object

# %%
df7['status']=df7['status'].str.replace('pd','paid')

# %%
df7
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           port express    refer to drawer
# 1    12-Jan-22                   mannee's bakery ltd.    refer to drawer
# 2    17-Jan-22         water and sewerage company inc  missing signature
# 3    17-Jan-22         water and sewerage company inc  missing signature
# 4    17-Jan-22         water and sewerage company inc  missing signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             verve inc.    refer to drawer
# 120  21-Dec-22                 frootsy  foods limited      payee missing
# 121  21-Dec-22            j.e. maxwell & company ltd.    refer to drawer
# 122  28-Dec-22               ernst and young services     refer to maker
# 123  29-Dec-22  clean ops service company (cosc) inc.    refer to drawer
#
#        amount      chq_no      chq_dt  status receipt_no          ministry
# ...

# %%
df8=df7

# %%
df8.to_csv('chq_22_clean_8.csv')

# %%
df7['status'].describe()
# Out:
# count      121
# unique       3
# top       paid
# freq        61
# Name: status, dtype: object

# %%
df7['status'].unique()
# Out:
# array(['unpaid', 'paid', nan, 'rt'], dtype=object)

# %%
df7['status']=df7['status'].str.replace('nan','paid').str.replace('rt','returned')

# %%
df8=df7

# %%
df8.to_csv('chq_22_clean_8.csv')

# %%
df7['ministry'].unique()
# Out:
# array(['customs & excise', 'commerce', 'inland revenue', 'unknown',
#        'supreme court', 'sub-accountant vieux-fort', 'infrastructure',
#        'registry of companies', 'sub-accountant vieux fort',
#        'postmaster general', 'printry', 'customs &excise', 'planning',
#        'inland revenue '], dtype=object)

# %%
df7['ministry'].describe()
# Out:
# count                124
# unique                14
# top       inland revenue
# freq                  46
# Name: ministry, dtype: object

# %%
df7['ministry']=df7['ministry'].str.replace('customs &excise','customs & excise').str.replace('unknown','inland revenue ')

# %%
df7['ministry'].unique()
# Out:
# array(['customs & excise', 'commerce', 'inland revenue',
#        'inland revenue ', 'supreme court', 'sub-accountant vieux-fort',
#        'infrastructure', 'registry of companies',
#        'sub-accountant vieux fort', 'postmaster general', 'printry',
#        'planning'], dtype=object)

# %%
df7['ministry']=df7['ministry'].str.replace('inland revenue ','inland revenue')

# %%
df7['ministry'].unique()
# Out:
# array(['customs & excise', 'commerce', 'inland revenue', 'supreme court',
#        'sub-accountant vieux-fort', 'infrastructure',
#        'registry of companies', 'postmaster general', 'printry',
#        'planning'], dtype=object)

# %%
df8=df7

# %%
df7['ministry']=df7['ministry'].str.replace('sub-accountant vieux fort','sub-accountant vieux-fort')

# %%
df7['owners'].unique()
# Out:
# array(['port express', "mannee's bakery ltd.",
#        'water and sewerage company inc', 'ba law chambers inc.',
#        'federal express-st.lucia limited', 'pals marketinginc.',
#        'avant-blue medical clinic inc.', 'sylvester anthony chambers',
#        "mannee's bakery ltd", 'mango sportwear limited', 'andie george',
#        'nj & co. corporate mgmt. srvcs. ltd.',
#        'neal james - t/a platinum car & jeep rental',
#        'raj maraj international agencies', 'unknown',
#        'trans caribbean 2000 ltd', 'west technology group inc.',
#        'gill rudolph boriel', 'healing mini spar', "elena's ice cream",
#        'skiltech limited', 'gid services inc.',
#        'united shipping agencies', 'emagine solutions inc.',
#        'frootsy foods limited',
#        'davison harris &/ or chrisie harris- destiny lounge',
#        'forest springs limited', 'ultramart inc.',
#        'sandals grande st.lucian ', 'creative smiles',
# ...

# %%
df7['status']=df7['status'].str.replace('un','unpaid')

# %%
df7
# Out:
#        debited                                 owners             reason  \
# 0     5-Jan-22                           port express    refer to drawer
# 1    12-Jan-22                   mannee's bakery ltd.    refer to drawer
# 2    17-Jan-22         water and sewerage company inc  missing signature
# 3    17-Jan-22         water and sewerage company inc  missing signature
# 4    17-Jan-22         water and sewerage company inc  missing signature
# ..         ...                                    ...                ...
# 119  20-Dec-22                             verve inc.    refer to drawer
# 120  21-Dec-22                 frootsy  foods limited      payee missing
# 121  21-Dec-22            j.e. maxwell & company ltd.    refer to drawer
# 122  28-Dec-22               ernst and young services     refer to maker
# 123  29-Dec-22  clean ops service company (cosc) inc.    refer to drawer
#
#        amount      chq_no      chq_dt  status receipt_no          ministry
# ...

# %%
df7['status'] = df7['status'].fillna('unpaid')

# %%
df7['ministry'].unique()
# Out:
# array(['customs & excise', 'commerce', 'inland revenue', 'supreme court',
#        'sub-accountant vieux-fort', 'infrastructure',
#        'registry of companies', 'postmaster general', 'printry',
#        'planning'], dtype=object)

# %%
df7.to_csv('chq_22_clean_8.csv')
